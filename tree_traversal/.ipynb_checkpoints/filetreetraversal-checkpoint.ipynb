# %%
'''
Code written in DAT-129 during class session for traversing
an arbitrary file tree on a variety of platforms

Functionality at the end of class was to visit each
directory in a tree, send the list of files within to a method
which then examines each file individually, 
extracts its size, and strips the file extension off
with a regular expression.

Students were encouraged to contiue this project by building
variables to store metrics about the trees, such as 
maximum depth and breadth, average file size, 
total tree size, and so forth.

'''
from zipfile import ZipFile
import os
import re

'''
Uncomment these two lines to test out the extraction of a
zip archive called darien-tree.zip that must be located
in the same directory as this script
'''
# with ZipFile('darien-tree.zip', 'r') as zipObj:
#     zipObj.extractall()

# Utility function for exploring features of a list of files
# discovered from our os.walk method
def interrogateFiles(dirname, fileList):
    # Build the regular expression once, 
    # and store the compiled version for use in the loop
    # We save overhead by compiling only once, and not once
    # for each file we interrogate
    # the (  ) in the regexp create a group
    # which we then mark with $ to instruct the engine
    # to start looking for a match at the right end of the given string
    regexp = re.compile('(\.\w+)$')
    for f in fileList:
        # rebuld the file name from the given directory name
        # and the OS-specific file path separator we can get with os.sep
        # and the filename we get from our iterator
        fn = dirname + str(os.sep) + f
        print('file name: ', fn)
        print('file size: ', end='')
        
        if os.path.isfile(fn):
            print(os.path.getsize(fn),'B')
            match = re.search(regexp, fn)
            if match:
                print('extension: ', match.group(0))

# %%
# traversing directory tree rooted in my current location    
for loc, dirs, files in os.walk('.'):
    print('visiting location: ', loc)
    # pass the current iteration's object pair (ignoring dirs)
    # to our method dedicated to looking at a list of files 
    # in any arbitrary file location
    interrogateFiles(loc, files)
# Out:
# .
# file size: ./ostraversal.ipynb
# 1353 B
# extension:  .ipynb
# file size: ./darien-tree.zip
# 314882 B
# extension:  .zip
# file size: ./filetreetraversal.ipynb
# 8612 B
# extension:  .ipynb
# ./darien-tree
# file size: ./darien-tree/Art.zip
# 139944 B
# extension:  .zip
# file size: ./darien-tree/treelog.txt
# 718 B
# extension:  .txt
# file size: ./darien-tree/LeafLogGang.ods
# 9028 B
# extension:  .ods
# file size: ./darien-tree/.~lock.LeafLogGang.ods#
# 103 B
# file size: ./darien-tree/TreeVisualization.docx
# 12504 B
# extension:  .docx
# ./darien-tree/Art
# ./darien-tree/Art/Art Forms
# ./darien-tree/Art/Art Forms/Drawing
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Shape
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Shape/Examples
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Shape/Examples/geometricorganic.jpg
# 14050 B
# extension:  .jpg
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Shape/Info
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Shape/Info/ShapeInfo.url
# 165 B
# extension:  .url
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space/Examples
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space/Examples/colorchangeswithDistance.jpg
# 7096 B
# extension:  .jpg
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space/Examples/Overlapping.jpg
# 10388 B
# extension:  .jpg
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space/Examples/sizefurtherAway.jpg
# 10677 B
# extension:  .jpg
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space/Examples/perspective.jpg
# 5707 B
# extension:  .jpg
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space/Examples/furtherAway.jpg
# 11715 B
# extension:  .jpg
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space/Examples/lessDetailFartherAway.jpg
# 14294 B
# extension:  .jpg
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space/Info
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Space/Info/SpaceInfo.url
# 149 B
# extension:  .url
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Texture
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Texture/Examples
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Texture/Examples/texture2.jpg
# 4740 B
# extension:  .jpg
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Texture/Examples/texture1.JPG
# 12177 B
# extension:  .JPG
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Texture/Info
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Texture/Info/Texture Info.url
# 141 B
# extension:  .url
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Value
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Value/Examples
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Value/Examples/valuescale.gif
# 2344 B
# extension:  .gif
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Value/Examples/value1.gif
# 49306 B
# extension:  .gif
# ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Value/Info
# file size: ./darien-tree/Art/Art Forms/Drawing/Elements-Principles/Value/Info/ValueInfo.url
# 133 B
# extension:  .url
# ./darien-tree/Art/Art Forms/Sculpting
# file size: ./darien-tree/Art/Art Forms/Sculpting/David.jfif
# 4651 B
# extension:  .jfif
# ./root
# ./root/tools
# ./root/tools/hand_tools
# file size: ./root/tools/hand_tools/awl
# 0 B
# file size: ./root/tools/hand_tools/hammer
# 0 B
# file size: ./root/tools/hand_tools/shovel
# 0 B
# ./root/tools/power_tools
# file size: ./root/tools/power_tools/sander
# 0 B
# file size: ./root/tools/power_tools/bandsaw
# 0 B
# file size: ./root/tools/power_tools/tablesaw
# 0 B
# ./.ipynb_checkpoints
# file size: ./.ipynb_checkpoints/ostraversal-checkpoint.ipynb
# 72 B
# extension:  .ipynb
# file size: ./.ipynb_checkpoints/filetreetraversal-checkpoint.ipynb
# 7570 B
# extension:  .ipynb
