# %%
import numpy
import panada
import csv
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f170f6c2fb87> in <module>()
#       1 import numpy
# ----> 2 import panada
#       3 import csv
#       4 import os
#
# ModuleNotFoundError: No module named 'panada'

# %%
import pandas as pd

# %%
drivers = pd.read_csv('distracteds1.csv', index_col=0)

# %% [raw]
# print(drivers.index)

# %%
drivers[drivers>0]
# Out:
#      Using Tech Device  Number Passengers Vehicle Type
# ID
# 1                  NaN                1.0            p
# 2                  NaN                2.0            p
# 3                  NaN                4.0            p
# 4                  NaN                1.0            p
# 5                  NaN                1.0            p
# 6                  NaN                1.0            p
# 7                  NaN                1.0            p
# 8                  NaN                2.0            p
# 9                  NaN                2.0            p
# 10                 NaN                1.0            p
# 11                 NaN                NaN           -9
# 12                 NaN                1.0            p
# 13                 NaN                1.0            p
# 14                 NaN                1.0            p
# 15                 1.0                1.0            p
# 16                 NaN                1.0            p
# ...
